# %% [markdown]
# <a href="https://colab.research.google.com/github/JinnnnyHong/machine-learning_math-/blob/main/Seaborn_and__Mat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seaborn and Matplotlib HW

# %%
people = ['Ann','Brandon','Chen','David','Emily','Farook',
          'Gagan','Hamish','Imran','Julio','Katherine','Lily']
age = [21,12,32,45,37,18,28,52,5,40,48,15]
weight = [55,35,77,68,70,60,72,69,18,65,82,48]
height = [160,135,170,165,173,168,175,159,105,171,155,158]

# %% [markdown]
# 1. matplotlib plt라는 이름으로 import

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# plt.scatter(x,y) : x = x-axis, y = y-axis

# %%
plt.scatter(age, height)
plt.show()

# %%
# figure size 설정
plt.figure(figsize=(8,6))

# 그래프 제목, 폰트 사이즈, 폰트 설정
plt.title("Plot of Age vs. Height (in cms)\n",fontsize=20, fontstyle='italic')

# X- and Y-label with fontsize
plt.xlabel("Age (years)",fontsize=16)
plt.ylabel("Height (cms)",fontsize=16)

# 그리드 설정
plt.grid (True) 

# y축 범위 설정
plt.ylim(100,200)

# x,y축 눈금 설정
plt.xticks([i*5 for i in range(12)],fontsize=15)
plt.yticks(fontsize=15)

# Main plotting function with choice of color, marker size, and marker edge color
plt.scatter(x=age,y=height,c='orange',s=150,edgecolors='k')

# Adding bit of text to the plot
plt.text(x=15,y=105,s="Height increaes up to around \n20 years and then tapers off",fontsize=15, 
         rotation=30, linespacing=2)
plt.text(x=22,y=185,s="Nobody has a height beyond 180 cm",fontsize=15)

# x값이 20인 수직선 설정
plt.vlines(x=20,ymin=100,ymax=180,linestyles='dashed',color='blue',lw=3)

# y값이 180인 수직선 만들기
plt.hlines(y=180,xmin=0,xmax=55,linestyles='dashed',color='red',lw=3)

# Adding a legend
plt.legend(['Height in cms'],loc=2,fontsize=14)

# 그래프 보기
plt.show()

# %% [markdown]
# 4-1
# plt.bar(x=people,height=weight, width=0.6,color='orange',edgecolor='k',alpha=0.6)
# x = x축 설정, y = y축 설정, width = 막대폭, color = 그래프 색깔, edgecolor = 막대 테두리 색깔, alpha = 투명도

# %%
plt.bar(x=people,height=weight, width=0.6,color='orange',edgecolor='k',alpha=0.6)
# Out:
# <BarContainer object of 12 artists>

# %%
#4-2 

plt.figure(figsize=(10, 2))
plt.title("People's weight in kgs",fontsize=10, fontstyle='italic')
# Main plot function 'bar'
plt.bar(x=people,height=weight, width=0.8,color='blue',edgecolor='black',alpha=1)
plt.xlabel("People",fontsize=10)
plt.xticks(fontsize=8,rotation=30)
plt.yticks(fontsize=8)
plt.ylabel("Weight (in kgs)",fontsize=12)
plt.show()

# %% [markdown]
# ## 5-1.
# plt.figure(figsize=(7,5)) plt.hist(weight,color='red',edgecolor='k', alpha=0.75,bins=5) plt.xticks(fontsize=15)
#
# figsize = figure size(x축길이, y축 길이), weight변수, color = 색깔, edgecolor = 테두리 색깔, alpha = 투명도, bins = 막대 개수, xticks(fontsize= 15) = x축 눈금 길이 설정

# %%
#5-2

import numpy as np

plt.figure(figsize=(10,8))

# Main plot function 'hist'

plt.hist(weight,color='yellow',edgecolor='white', alpha= 0.5,bins=4)


plt.title("Histogram of patient weight",fontsize=20)
plt.xlabel("Weight in kgs",fontsize=8)
plt.xticks(fontsize= 7)
plt.yticks(fontsize=7)
plt.show()

# %% [markdown]
# 6. days = 1부터 30까지의 배열
#
# candidate_A = 50 + day * 0.07 + 2*랜덤하게 추출된 난수
#
# candidate_A = 50 - day * 0.1 + 3*랜덤하게 추출된 난수

# %%
days = np.arange(1,31)
candidate_A = 50+days*0.07+2*np.random.randn(30)
candidate_B = 50-days*0.1+3*np.random.randn(30)

# %% [markdown]
# 7. ymin = candidate_A, candidate_B 중에서 최솟값
# xmax = candidate_A, candidate_B 중에서 최댓값

# %%
ymin = min(candidate_A.min(),candidate_B.min())
ymax = max(candidate_A.max(),candidate_B.max())

# %% [markdown]
# 8-1. plt.plot(days,candidate_A,'o-',markersize=10,c='blue',lw=2)
# day와 condidate을 이용한 선 그래프, 'o-': 데이터 포인터에 원 모양으로 하고, 선으로 연결한다는 뜻, markersize = 마크 사이즈, c = 선과 마크의 색깔, lw = 선의 굵기

# %%
#8-2
plt.style.use('fivethirtyeight')

plt.figure(figsize=(12,5))
plt.title("Time series plot of poll percentage over a month\n",fontsize=15, fontstyle='italic')
plt.xlabel("Days",fontsize=16)
plt.ylabel("Poll percentage (%)",fontsize=14)
plt.grid (True)
plt.ylim(ymin*0.77,ymax*0.99)
plt.xticks([i*2 for i in range(16)],fontsize=10)
plt.yticks(fontsize=15)

# Main plotting function - plot (note markersize, lw (linewidth) arguments)
plt.plot(days,candidate_A,'o-',markersize=8,c='blue',lw=3)
plt.plot(days,candidate_B,'^-',markersize=8,c='green',lw=4)

plt.legend(['Poll percentage of candidate A (%)', 'Poll percentage of candidate B (%)'],loc=2,fontsize=14)
plt.show()

# %% [markdown]
# 9. boxplot를 실행해 보고, plt.boxplot(x=[candidate_A,candidate_B],showmeans=True) 내부의 옵션의 뜻을 말하시오.
#
# x = 분포를 나타내는 데이터를 리스트 형태로 입력, A와 B의 분포 비교
# showmeans = 상자그림 내에 평균값을 나타내는 옵션
# True = 분포의 평균값이 나옴

# %%
plt.style.use('ggplot')


# Note how to convert default numerical x-axis ticks to the list of string by passing two lists 
plt.boxplot(x=[candidate_A,candidate_B],showmeans=True)
plt.grid(True)
plt.xticks([1,2],['Candidate A','Candidate B'])

#plt.yticks(fontsize=15)

plt.show()

# %%
import pandas as pd

# %% [markdown]
# 10.
# Wget: 웹 서버로부터 파일을 다운받을 때 사용하는 프로그램
#
# !rm -rf: 기존에 존재하는 디렉토리를 삭제
#
# !mkdir : 디렉토리를 생성
#
# !mv: 다운로드한 데이터 파일들을 디렉토리로 이동

# %%
# !wget "https://raw.githubusercontent.com/tirthajyoti/Stats_data_science_ValleyML/master/Notebooks/Data/wine.data.csv"
# !wget "https://raw.githubusercontent.com/tirthajyoti/Stats_data_science_ValleyML/master/Notebooks/Data/Height_Weight.xlsx"

! rm -rf Data
# !mkdir Data

# !mv wine.data.csv Data/
# !mv Height_Weight.xlsx Data/
# Out:
# --2023-04-05 11:04:04--  https://raw.githubusercontent.com/tirthajyoti/Stats_data_science_ValleyML/master/Notebooks/Data/wine.data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11481 (11K) [text/plain]
# Saving to: ‘wine.data.csv’
#
# wine.data.csv       100%[===================>]  11.21K  --.-KB/s    in 0s
#
# 2023-04-05 11:04:04 (26.2 MB/s) - ‘wine.data.csv’ saved [11481/11481]
#
# --2023-04-05 11:04:04--  https://raw.githubusercontent.com/tirthajyoti/Stats_data_science_ValleyML/master/Notebooks/Data/Height_Weight.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %% [markdown]
# 11. csv 읽는 것

# %%
df = pd.read_csv('Data/wine.data.csv')

# %%
df.head()


import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
df.plot.scatter('Alcohol','Color intensity')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
#13-2
df.plot.scatter('Color intensity','Alcohol')
plt.show()

# %% [markdown]
# 14-1. df['Alcohol'].plot.hist(bins=20,figsize=(5,5),edgecolor='k') 내부의 옵션
#
# alcohol 데이터 프레임의 히스토그램
# bins = 구간 개수
# figsize = 크기 설정
# adgecolor = 테두리 색

# %%
df['Alcohol'].plot.hist(bins=10,figsize=(10,10),edgecolor='k')

plt.xlabel('Alcohol percentage')
plt.show()

# %% [markdown]
# 15. seaborn을 sns라는 이름으로 임포트

# %%
import seaborn as sns

# %% [markdown]
# 16. x축은 class, y축은 alcohol로, df데이터로 상자 그림

# %%
sns.boxplot(x='Class',y='Alcohol',data=df)
# Out:
# <Axes: xlabel='Class', ylabel='Alcohol'>

# %% [markdown]
# 17-1. sns.violinplot(x='Class',y='Alcohol',data=df)
#
# x축은 class, y축은 alcohol이고, 데이터는 df인 바이올린 플롯

# %%
#17-2
sns.violinplot(x='Alcohol',y='Class',data=df)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Class'>

# %%
sns.regplot(x='Alcohol',y='Color intensity',data=df)
plt.show()

# %%
sns.lmplot(x='Alcohol',y='Color intensity',hue='Class',data=df)
plt.show()

# %%
import numpy as np

# %% [markdown]
# 18.  corrcoef(): 인자로 전달된 배열의 행 또는 열 간의 상관계수를 계산
# rowvar=False : df의 각 컬럼이 변수(variable)로 생각

# %%
corr_mat=np.corrcoef(df,rowvar=False)

# %% [markdown]
# 19. corr_mat의 행렬

# %%
corr_mat.shape
# Out:
# (14, 14)

# %% [markdown]
# 20. corr_mat데이터를 col = df.col, index는 df.col로 설정

# %%
corr_df = pd.DataFrame(corr_mat,columns=df.columns,index=df.columns)

# %% [markdown]
# 21. corr_mat의 소수점 셋째자리까지 반올림

# %%
print(np.round(corr_mat,3))
# Out:
# [[ 1.    -0.328  0.438 -0.05   0.518 -0.209 -0.719 -0.847  0.489 -0.499
#    0.266 -0.617 -0.788 -0.634]
#  [-0.328  1.     0.094  0.212 -0.31   0.271  0.289  0.237 -0.156  0.137
#    0.546 -0.072  0.072  0.644]
#  [ 0.438  0.094  1.     0.164  0.289 -0.055 -0.335 -0.411  0.293 -0.221
#    0.249 -0.561 -0.369 -0.192]
#  [-0.05   0.212  0.164  1.     0.443  0.287  0.129  0.115  0.186  0.01
#    0.259 -0.075  0.004  0.224]
#  [ 0.518 -0.31   0.289  0.443  1.    -0.083 -0.321 -0.351  0.362 -0.197
#    0.019 -0.274 -0.277 -0.441]
#  [-0.209  0.271 -0.055  0.287 -0.083  1.     0.214  0.196 -0.256  0.236
#    0.2    0.055  0.066  0.393]
#  [-0.719  0.289 -0.335  0.129 -0.321  0.214  1.     0.865 -0.45   0.612
#   -0.055  0.434  0.7    0.498]
#  [-0.847  0.237 -0.411  0.115 -0.351  0.196  0.865  1.    -0.538  0.653
#   -0.172  0.543  0.787  0.494]
#  [ 0.489 -0.156  0.293  0.186  0.362 -0.256 -0.45  -0.538  1.    -0.366
#    0.139 -0.263 -0.503 -0.311]
# ...

# %%
sns.heatmap(corr_df,linewidth=0.5,cmap='magma')
plt.show()
